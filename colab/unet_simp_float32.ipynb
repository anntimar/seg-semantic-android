# %%
# !pip -q install sng4onnx

# %%
import tensorflow as tf, onnx2tf, sng4onnx
print("Pronto! TF:", tf.__version__)
# Out:
# Pronto! TF: 2.17.1

# %%
# Reinicie o runtime (Runtime > Restart session) e rode isto primeiro:
# !pip -q install --upgrade pip
# !pip -q install --prefer-binary onnx==1.16.2 tensorflow==2.17.1 onnx-graphsurgeon
# !pip -q install "onnx2tf>=1.21.0" ai-edge-litert tf-keras==2.17.0

import tensorflow as tf, onnx, onnx2tf, onnx_graphsurgeon, ai_edge_litert, tf_keras
print("OK | TF:", tf.__version__)
# Out:
# OK | TF: 2.17.1

# %%
import torch, torch.nn as nn, onnx, os
from google.colab import files

# (opcional) usa onnxsim se estiver disponível; se não, segue sem
try:
    from onnxsim import simplify
    USE_SIM = True
except Exception:
    simplify = None; USE_SIM = False
print("onnxsim:", "on" if USE_SIM else "off")

IMG_SIZE = 256
CHECKPOINT = "/content/unet_best.pt"   # <-- seu arquivo

# U-Net (mesma do treino)
class ConvBlock(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1), nn.BatchNorm2d(out_c), nn.ReLU(inplace=True),
            nn.Conv2d(out_c, out_c, 3, padding=1), nn.BatchNorm2d(out_c), nn.ReLU(inplace=True),
        )
    def forward(self, x): return self.net(x)

class UNet(nn.Module):
    def __init__(self, in_channels=3, base=32, out_channels=1):
        super().__init__()
        self.enc1 = ConvBlock(in_channels, base)
        self.enc2 = ConvBlock(base, base*2)
        self.enc3 = ConvBlock(base*2, base*4)
        self.enc4 = ConvBlock(base*4, base*8)
        self.pool = nn.MaxPool2d(2)
        self.bottleneck = ConvBlock(base*8, base*16)
        self.up4 = nn.ConvTranspose2d(base*16, base*8, 2, stride=2)
        self.dec4 = ConvBlock(base*16, base*8)
        self.up3 = nn.ConvTranspose2d(base*8, base*4, 2, stride=2)
        self.dec3 = ConvBlock(base*8, base*4)
        self.up2 = nn.ConvTranspose2d(base*4, base*2, 2, stride=2)
        self.dec2 = ConvBlock(base*4, base*2)
        self.up1 = nn.ConvTranspose2d(base*2, base, 2, stride=2)
        self.dec1 = ConvBlock(base*2, base)
        self.head = nn.Conv2d(base, out_channels, 1)
    def forward(self, x):
        e1 = self.enc1(x); p1 = self.pool(e1)
        e2 = self.enc2(p1); p2 = self.pool(e2)
        e3 = self.enc3(p2); p3 = self.pool(e3)
        e4 = self.enc4(p3); p4 = self.pool(e4)
        b = self.bottleneck(p4)
        d4 = self.up4(b); d4 = torch.cat([d4, e4], dim=1); d4 = self.dec4(d4)
        d3 = self.up3(d4); d3 = torch.cat([d3, e3], dim=1); d3 = self.dec3(d3)
        d2 = self.up2(d3); d2 = torch.cat([d2, e2], dim=1); d2 = self.dec2(d2)
        d1 = self.up1(d2); d1 = torch.cat([d1, e1], dim=1); d1 = self.dec1(d1)
        return self.head(d1)

# 1) carregar checkpoint
model = UNet().eval()
model.load_state_dict(torch.load(CHECKPOINT, map_location="cpu"))

# 2) exportar para ONNX
dummy = torch.randn(1,3,IMG_SIZE,IMG_SIZE)
torch.onnx.export(model, dummy, "unet.onnx",
                  input_names=["input"], output_names=["logits"],
                  opset_version=17, do_constant_folding=True)

# 3) (opcional) simplificar
if USE_SIM:
    m = onnx.load("unet.onnx")
    m_simp, ok = simplify(m)
    assert ok, "Falha ao simplificar ONNX"
    onnx.save(m_simp, "unet_simp.onnx")
else:
    os.replace("unet.onnx", "unet_simp.onnx")

# 4) converter para TF + TFLite FP32
from onnx2tf import convert
convert(
    input_onnx_file_path="unet_simp.onnx",
    output_folder_path="unet_tf",
    output_integer_quantized_tflite=False,     # FP32
    copy_onnx_input_output_names_to_tflite=True,
)

# 5) baixar o .tflite
files.download("unet_tf/model_float32.tflite")
# Out:
# onnxsim: off
#
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnx2tf/onnx2tf.py", line 684, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'onnxsim'
#
# WARNING: Failed to optimize the onnx file.
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: input shape: [1, 3, 256, 256] dtype: float32
# WARNING: The optimization process for shape estimation is skipped because it contains OPs that cannot be inferred by the standard onnxruntime.
# WARNING: name 'ort' is not defined
#
# INFO: 2 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc1/net/net.0/Conv
# INFO:  input_name.1: input shape: [1, 3, 256, 256] dtype: float32
# INFO:  input_name.2: onnx::Conv_205 shape: [32, 3, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_206 shape: [32] dtype: float32
# INFO:  output_name.1: /enc1/net/net.0/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: input shape: (1, 256, 256, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 3 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc1/net/net.2/Relu
# INFO:  input_name.1: /enc1/net/net.0/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  output_name.1: /enc1/net/net.2/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 4 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc1/net/net.3/Conv
# INFO:  input_name.1: /enc1/net/net.2/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  input_name.2: onnx::Conv_208 shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_209 shape: [32] dtype: float32
# INFO:  output_name.1: /enc1/net/net.3/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 5 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc1/net/net.5/Relu
# INFO:  input_name.1: /enc1/net/net.3/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  output_name.1: /enc1/net/net.5/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_1/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_1/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 6 / 50
# INFO: onnx_op_type: MaxPool onnx_op_name: /pool/MaxPool
# INFO:  input_name.1: /enc1/net/net.5/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  output_name.1: /pool/MaxPool_output_0 shape: [1, 32, 128, 128] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_1/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d/MaxPool2d:0 shape: (1, 128, 128, 32) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 7 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc2/net/net.0/Conv
# INFO:  input_name.1: /pool/MaxPool_output_0 shape: [1, 32, 128, 128] dtype: float32
# INFO:  input_name.2: onnx::Conv_211 shape: [64, 32, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_212 shape: [64] dtype: float32
# INFO:  output_name.1: /enc2/net/net.0/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d/MaxPool2d:0 shape: (1, 128, 128, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 8 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc2/net/net.2/Relu
# INFO:  input_name.1: /enc2/net/net.0/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  output_name.1: /enc2/net/net.2/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_2/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_2/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 9 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc2/net/net.3/Conv
# INFO:  input_name.1: /enc2/net/net.2/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  input_name.2: onnx::Conv_214 shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_215 shape: [64] dtype: float32
# INFO:  output_name.1: /enc2/net/net.3/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_2/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 10 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc2/net/net.5/Relu
# INFO:  input_name.1: /enc2/net/net.3/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  output_name.1: /enc2/net/net.5/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_3/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_3/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 11 / 50
# INFO: onnx_op_type: MaxPool onnx_op_name: /pool_1/MaxPool
# INFO:  input_name.1: /enc2/net/net.5/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  output_name.1: /pool_1/MaxPool_output_0 shape: [1, 64, 64, 64] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_3/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d_1/MaxPool2d:0 shape: (1, 64, 64, 64) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 12 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc3/net/net.0/Conv
# INFO:  input_name.1: /pool_1/MaxPool_output_0 shape: [1, 64, 64, 64] dtype: float32
# INFO:  input_name.2: onnx::Conv_217 shape: [128, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_218 shape: [128] dtype: float32
# INFO:  output_name.1: /enc3/net/net.0/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose/transpose:0 shape: (1, 64, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_5/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 13 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc3/net/net.2/Relu
# INFO:  input_name.1: /enc3/net/net.0/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  output_name.1: /enc3/net/net.2/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_5/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_4/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 14 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc3/net/net.3/Conv
# INFO:  input_name.1: /enc3/net/net.2/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  input_name.2: onnx::Conv_220 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_221 shape: [128] dtype: float32
# INFO:  output_name.1: /enc3/net/net.3/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_4/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_6/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 15 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc3/net/net.5/Relu
# INFO:  input_name.1: /enc3/net/net.3/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  output_name.1: /enc3/net/net.5/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_6/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_5/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 16 / 50
# INFO: onnx_op_type: MaxPool onnx_op_name: /pool_2/MaxPool
# INFO:  input_name.1: /enc3/net/net.5/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  output_name.1: /pool_2/MaxPool_output_0 shape: [1, 128, 32, 32] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_5/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d_2/MaxPool2d:0 shape: (1, 32, 32, 128) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 17 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc4/net/net.0/Conv
# INFO:  input_name.1: /pool_2/MaxPool_output_0 shape: [1, 128, 32, 32] dtype: float32
# INFO:  input_name.2: onnx::Conv_223 shape: [256, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_224 shape: [256] dtype: float32
# INFO:  output_name.1: /enc4/net/net.0/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d_2/MaxPool2d:0 shape: (1, 32, 32, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (256,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_7/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 18 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc4/net/net.2/Relu
# INFO:  input_name.1: /enc4/net/net.0/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  output_name.1: /enc4/net/net.2/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_7/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_6/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 19 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /enc4/net/net.3/Conv
# INFO:  input_name.1: /enc4/net/net.2/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  input_name.2: onnx::Conv_226 shape: [256, 256, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_227 shape: [256] dtype: float32
# INFO:  output_name.1: /enc4/net/net.3/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_6/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (256,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_8/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 20 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /enc4/net/net.5/Relu
# INFO:  input_name.1: /enc4/net/net.3/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  output_name.1: /enc4/net/net.5/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_8/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_7/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 21 / 50
# INFO: onnx_op_type: MaxPool onnx_op_name: /pool_3/MaxPool
# INFO:  input_name.1: /enc4/net/net.5/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  output_name.1: /pool_3/MaxPool_output_0 shape: [1, 256, 16, 16] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_7/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d_3/MaxPool2d:0 shape: (1, 16, 16, 256) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 22 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /bottleneck/net/net.0/Conv
# INFO:  input_name.1: /pool_3/MaxPool_output_0 shape: [1, 256, 16, 16] dtype: float32
# INFO:  input_name.2: onnx::Conv_229 shape: [512, 256, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_230 shape: [512] dtype: float32
# INFO:  output_name.1: /bottleneck/net/net.0/Conv_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d_3/MaxPool2d:0 shape: (1, 16, 16, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 512) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (512,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
#
# INFO: 23 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /bottleneck/net/net.2/Relu
# INFO:  input_name.1: /bottleneck/net/net.0/Conv_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO:  output_name.1: /bottleneck/net/net.2/Relu_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_9/Add:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_8/Relu:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
#
# INFO: 24 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /bottleneck/net/net.3/Conv
# INFO:  input_name.1: /bottleneck/net/net.2/Relu_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO:  input_name.2: onnx::Conv_232 shape: [512, 512, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_233 shape: [512] dtype: float32
# INFO:  output_name.1: /bottleneck/net/net.3/Conv_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_8/Relu:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 512, 512) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (512,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_10/Add:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
#
# INFO: 25 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /bottleneck/net/net.5/Relu
# INFO:  input_name.1: /bottleneck/net/net.3/Conv_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO:  output_name.1: /bottleneck/net/net.5/Relu_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_10/Add:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_9/Relu:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
#
# INFO: 26 / 50
# INFO: onnx_op_type: ConvTranspose onnx_op_name: /up4/ConvTranspose
# INFO:  input_name.1: /bottleneck/net/net.5/Relu_output_0 shape: [1, 512, 16, 16] dtype: float32
# INFO:  input_name.2: up4.weight shape: [512, 256, 2, 2] dtype: float32
# INFO:  input_name.3: up4.bias shape: [256] dtype: float32
# INFO:  output_name.1: /up4/ConvTranspose_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: conv2d_transpose_v2
# INFO:  input.1.input: name: tf.nn.relu_9/Relu:0 shape: (1, 16, 16, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.filters: shape: (2, 2, 256, 512) dtype: <dtype: 'float32'>
# INFO:  input.3.output_shape: val: [1, 32, 32, 256]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  input.8.bias: shape: (256,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 27 / 50
# INFO: onnx_op_type: Concat onnx_op_name: /Concat
# INFO:  input_name.1: /up4/ConvTranspose_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  input_name.2: /enc4/net/net.5/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  output_name.1: /Concat_output_0 shape: [1, 512, 32, 32] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.add_11/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_7/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat/concat:0 shape: (1, 32, 32, 512) dtype: <dtype: 'float32'>
#
# INFO: 28 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec4/net/net.0/Conv
# INFO:  input_name.1: /Concat_output_0 shape: [1, 512, 32, 32] dtype: float32
# INFO:  input_name.2: onnx::Conv_235 shape: [256, 512, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_236 shape: [256] dtype: float32
# INFO:  output_name.1: /dec4/net/net.0/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat/concat:0 shape: (1, 32, 32, 512) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 512, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (256,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_12/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 29 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec4/net/net.2/Relu
# INFO:  input_name.1: /dec4/net/net.0/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  output_name.1: /dec4/net/net.2/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_12/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_10/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 30 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec4/net/net.3/Conv
# INFO:  input_name.1: /dec4/net/net.2/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  input_name.2: onnx::Conv_238 shape: [256, 256, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_239 shape: [256] dtype: float32
# INFO:  output_name.1: /dec4/net/net.3/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_10/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (256,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 31 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec4/net/net.5/Relu
# INFO:  input_name.1: /dec4/net/net.3/Conv_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  output_name.1: /dec4/net/net.5/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_13/Add:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_11/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
#
# INFO: 32 / 50
# INFO: onnx_op_type: ConvTranspose onnx_op_name: /up3/ConvTranspose
# INFO:  input_name.1: /dec4/net/net.5/Relu_output_0 shape: [1, 256, 32, 32] dtype: float32
# INFO:  input_name.2: up3.weight shape: [256, 128, 2, 2] dtype: float32
# INFO:  input_name.3: up3.bias shape: [128] dtype: float32
# INFO:  output_name.1: /up3/ConvTranspose_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: conv2d_transpose_v2
# INFO:  input.1.input: name: tf.nn.relu_11/Relu:0 shape: (1, 32, 32, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.filters: shape: (2, 2, 128, 256) dtype: <dtype: 'float32'>
# INFO:  input.3.output_shape: val: [1, 64, 64, 128]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  input.8.bias: shape: (128,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_14/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 33 / 50
# INFO: onnx_op_type: Concat onnx_op_name: /Concat_1
# INFO:  input_name.1: /up3/ConvTranspose_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  input_name.2: /enc3/net/net.5/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  output_name.1: /Concat_1_output_0 shape: [1, 256, 64, 64] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.add_14/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_5/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat_1/concat:0 shape: (1, 64, 64, 256) dtype: <dtype: 'float32'>
#
# INFO: 34 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec3/net/net.0/Conv
# INFO:  input_name.1: /Concat_1_output_0 shape: [1, 256, 64, 64] dtype: float32
# INFO:  input_name.2: onnx::Conv_241 shape: [128, 256, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_242 shape: [128] dtype: float32
# INFO:  output_name.1: /dec3/net/net.0/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_1/concat:0 shape: (1, 64, 64, 256) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 256, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_15/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 35 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec3/net/net.2/Relu
# INFO:  input_name.1: /dec3/net/net.0/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  output_name.1: /dec3/net/net.2/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_15/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_12/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 36 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec3/net/net.3/Conv
# INFO:  input_name.1: /dec3/net/net.2/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  input_name.2: onnx::Conv_244 shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_245 shape: [128] dtype: float32
# INFO:  output_name.1: /dec3/net/net.3/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_12/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_16/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 37 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec3/net/net.5/Relu
# INFO:  input_name.1: /dec3/net/net.3/Conv_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  output_name.1: /dec3/net/net.5/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_16/Add:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_13/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
#
# INFO: 38 / 50
# INFO: onnx_op_type: ConvTranspose onnx_op_name: /up2/ConvTranspose
# INFO:  input_name.1: /dec3/net/net.5/Relu_output_0 shape: [1, 128, 64, 64] dtype: float32
# INFO:  input_name.2: up2.weight shape: [128, 64, 2, 2] dtype: float32
# INFO:  input_name.3: up2.bias shape: [64] dtype: float32
# INFO:  output_name.1: /up2/ConvTranspose_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: conv2d_transpose_v2
# INFO:  input.1.input: name: tf.nn.relu_13/Relu:0 shape: (1, 64, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.filters: shape: (2, 2, 64, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.output_shape: val: [1, 128, 128, 64]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  input.8.bias: shape: (64,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_17/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 39 / 50
# INFO: onnx_op_type: Concat onnx_op_name: /Concat_2
# INFO:  input_name.1: /up2/ConvTranspose_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  input_name.2: /enc2/net/net.5/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  output_name.1: /Concat_2_output_0 shape: [1, 128, 128, 128] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.add_17/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_3/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat_2/concat:0 shape: (1, 128, 128, 128) dtype: <dtype: 'float32'>
#
# INFO: 40 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec2/net/net.0/Conv
# INFO:  input_name.1: /Concat_2_output_0 shape: [1, 128, 128, 128] dtype: float32
# INFO:  input_name.2: onnx::Conv_247 shape: [64, 128, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_248 shape: [64] dtype: float32
# INFO:  output_name.1: /dec2/net/net.0/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_1/transpose:0 shape: (1, 128, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_19/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 41 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec2/net/net.2/Relu
# INFO:  input_name.1: /dec2/net/net.0/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  output_name.1: /dec2/net/net.2/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_19/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_14/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 42 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec2/net/net.3/Conv
# INFO:  input_name.1: /dec2/net/net.2/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  input_name.2: onnx::Conv_250 shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_251 shape: [64] dtype: float32
# INFO:  output_name.1: /dec2/net/net.3/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_14/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_20/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 43 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec2/net/net.5/Relu
# INFO:  input_name.1: /dec2/net/net.3/Conv_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  output_name.1: /dec2/net/net.5/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_20/Add:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_15/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
#
# INFO: 44 / 50
# INFO: onnx_op_type: ConvTranspose onnx_op_name: /up1/ConvTranspose
# INFO:  input_name.1: /dec2/net/net.5/Relu_output_0 shape: [1, 64, 128, 128] dtype: float32
# INFO:  input_name.2: up1.weight shape: [64, 32, 2, 2] dtype: float32
# INFO:  input_name.3: up1.bias shape: [32] dtype: float32
# INFO:  output_name.1: /up1/ConvTranspose_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: conv2d_transpose_v2
# INFO:  input.1.input: name: tf.nn.relu_15/Relu:0 shape: (1, 128, 128, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.filters: shape: (2, 2, 32, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.output_shape: val: [1, 256, 256, 32]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  input.8.bias: shape: (32,) dtype: float32
# INFO:  output.1.output: name: tf.math.add_21/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 45 / 50
# INFO: onnx_op_type: Concat onnx_op_name: /Concat_3
# INFO:  input_name.1: /up1/ConvTranspose_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  input_name.2: /enc1/net/net.5/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  output_name.1: /Concat_3_output_0 shape: [1, 64, 256, 256] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.math.add_21/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.nn.relu_1/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 3
# INFO:  output.1.output: name: tf.concat_3/concat:0 shape: (1, 256, 256, 64) dtype: <dtype: 'float32'>
#
# INFO: 46 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec1/net/net.0/Conv
# INFO:  input_name.1: /Concat_3_output_0 shape: [1, 64, 256, 256] dtype: float32
# INFO:  input_name.2: onnx::Conv_253 shape: [32, 64, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_254 shape: [32] dtype: float32
# INFO:  output_name.1: /dec1/net/net.0/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_3/concat:0 shape: (1, 256, 256, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_22/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 47 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec1/net/net.2/Relu
# INFO:  input_name.1: /dec1/net/net.0/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  output_name.1: /dec1/net/net.2/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_22/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_16/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 48 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /dec1/net/net.3/Conv
# INFO:  input_name.1: /dec1/net/net.2/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  input_name.2: onnx::Conv_256 shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: onnx::Conv_257 shape: [32] dtype: float32
# INFO:  output_name.1: /dec1/net/net.3/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_16/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_23/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 49 / 50
# INFO: onnx_op_type: Relu onnx_op_name: /dec1/net/net.5/Relu
# INFO:  input_name.1: /dec1/net/net.3/Conv_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  output_name.1: /dec1/net/net.5/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add_23/Add:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_17/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
#
# INFO: 50 / 50
# INFO: onnx_op_type: Conv onnx_op_name: /head/Conv
# INFO:  input_name.1: /dec1/net/net.5/Relu_output_0 shape: [1, 32, 256, 256] dtype: float32
# INFO:  input_name.2: head.weight shape: [1, 32, 1, 1] dtype: float32
# INFO:  input_name.3: head.bias shape: [1] dtype: float32
# INFO:  output_name.1: logits shape: [1, 1, 256, 256] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.relu_17/Relu:0 shape: (1, 256, 256, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 1) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (1,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_24/Add:0 shape: (1, 256, 256, 1) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# saved_model output complete!
# WARNING: If you want tflite input OP name and output OP name to match ONNX input and output names, convert them after installing "flatc". Also, do not use symbols such as slashes in input/output OP names. To install flatc, run the following command:
# wget https://github.com/PINTO0309/onnx2tf/releases/download/1.16.31/flatc.tar.gz && tar -zxvf flatc.tar.gz && sudo chmod +x flatc && sudo mv flatc /usr/bin/
# Float32 tflite output complete!
# WARNING: If you want tflite input OP name and output OP name to match ONNX input and output names, convert them after installing "flatc". Also, do not use symbols such as slashes in input/output OP names. To install flatc, run the following command:
# wget https://github.com/PINTO0309/onnx2tf/releases/download/1.16.31/flatc.tar.gz && tar -zxvf flatc.tar.gz && sudo chmod +x flatc && sudo mv flatc /usr/bin/
# Float16 tflite output complete!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-972137469.py in <cell line: 0>()
#      82
#      83 # 5) baixar o .tflite
# ---> 84 files.download("unet_tf/model_float32.tflite")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: unet_tf/model_float32.tflite

# %%
import os, glob
files = glob.glob("**/*.tflite", recursive=True)
print("TFLite encontrados:", files)
# Out:
# TFLite encontrados: ['unet_tf/unet_simp_float16.tflite', 'unet_tf/unet_simp_float32.tflite']

# %%
from google.colab import files
files.download("unet_tf/unet_simp_float32.tflite")
